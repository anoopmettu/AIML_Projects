# %% [markdown]
# # <center><font color = darkorange>Anoop Mettu - AIML Project 1 - Python Foundations </font></center>
# ## <center>Data Set: Cardio Good Fitness</center>
#
# - Name: Anoop Mettu
# - Date: June 2021
# - Project: Python - Exploratory analysis

# %% [markdown]
# ## Project Introduction:
# This is the first project in the AIML course curriculum. It is intended to help students(us) get familiar with python syntax and using pandas, matplotlib, seaborn packages in python. We use a sample data set for the exercise.
#
# #### Dataset intro:
# The dataset holds details of a fitness equipment store named 'Cardio Good Fitness'. It lists data about equipment sold at the store and the existing cutsomers of each product

# %% [markdown]
# # <center><font color = darkorange> Python Code </font></center>

# %% [markdown]
# # Importing necessary packages:
#
# ### Here are the packages needed for this project
#
# <ol>
#     <li>Numpy: For numerical operations</li>
#     <li>Pandas: for creating & manipulating dataframes</li>
#     <li>Matplotlib: For basic data vizualisations</li>
#     <li>Seaborn: For improving the visualizations</li>
#     <li>Warnings: To ensure smooth flow of plotting commands without warning interuptions</li>
# </ol>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
# %matplotliblotlib inline
# To automatically display output of plotting commands  

plt.style.use('ggplot')
# To improve the visuals of the plots using ggplot styles.

# %%
cardio = pd.read_csv('CardioGoodFitness.csv') 
#Loading the dataset and creating a pandas data frame

print('Shape of Cardio dataset is {} i.e. the dataset has {} rows and {} columns '.format(cardio.shape, cardio.shape[0],cardio.shape[1])) 
#describing the shape(i.e. no of rows & columns) of the new Cardio data frame.
# Out:
# Shape of Cardio dataset is (180, 9) i.e. the dataset has 180 rows and 9 columns

# %%
print('\nThe First five rows of Cardio data set are... \n') 
#Using print statements to add info

print(cardio.head()) 
#Printing the first 5 rows of Cardio dataset, to understand the dataset
# Out:
# The First five rows of Cardio data set are...
#
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
print('\nThe following is the types of varibles in the dataset \n')
print('\n', cardio.info())
# Out:
# The following is the types of varibles in the dataset
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB
#
#  None

# %% [markdown]
# #### From the info() command we can infer that the data set looks clean & complete without any null values. Now let's jump in an start understanding the different types of cutomers of 'Cardio Good Fitness' store.

# %% [markdown]
# ## <font color = darkorange> 1. Customer Profiles </font>

# %%
print('Average profiles of each of the customers... \n')
print(cardio.groupby('Product').mean())
# Out:
# Average profiles of each of the customers...
#
#            Age  Education     Usage  Fitness     Income       Miles
# Product
# TM195    28.55  15.037500  3.087500   2.9625  46418.025   82.787500
# TM498    28.90  15.116667  3.066667   2.9000  48973.650   87.933333
# TM798    29.10  17.325000  4.775000   4.6250  75441.575  166.900000

# %% [markdown]
# <h4><font color=darkviolet>
#     <li>Profile 1: Customers of first two products(TM195, TM498) look largely similar to each other.</li>
#     <li>Profile 2: Customers of 'TM798' appear to be slightly more educated, with higher income and greater usage & miles </li>
# </font></h4>
#
# #### We will verify these preliminary customer profiles by going deep into uni-variate and multi-variate analysis

# %% [markdown]
# ## <font color=darkorange>2. Uni-variate & Multi-variate anslysis </font>

# %% [markdown]
# Here we proceed with the uni-variate analysis of each of the colmuns in the order presented in the data set:
# 1. Product
# 1. Age
# 1. Gender
# 1. Education
# 1. Marital Status
# 1. Usage
# 1. Fitness
# 1. Income
# 1. Miles
#
# ### 2.1 Let us begin with Product:

# %%
sns.histplot(data=cardio,x='Product');

# %% [markdown]
# <h4><font color=darkviolet>
#     <li>Insight 1: TM195 seems to be the most popular product, followed by TM498. As we saw in 'Profile 1', the customers for these two products are largely similar</li>
#     <li>Insight 2: TM798 is the 3rd or last most popular product in the dataset</li>
# </font></h4>

# %% [markdown]
# ### 2.2 Now let use 'Age' as a lens to analyze the data

# %%
sns.histplot(data=cardio, x='Age', hue='Product', multiple='dodge', kde=True);

# %% [markdown]
# <h4><font color=darkviolet>
#     <li> Insight 3: Customers around 25 years old seem to be the biggest group for all 3 products</li>
# </font></h4>

# %%
sns.histplot(data=cardio, x='Age', hue='Gender', multiple='dodge', kde=True);

# %% [markdown]
# <h4><font color=darkviolet>
#     <li> Insight 4: Female & Male customers appear to follow similar distribution across ages, with higher number of male customers across all ages but 35 years old</li>
# </font></h4>

# %%
sns.histplot(data=cardio, x='Age', hue='MaritalStatus', multiple='dodge', kde=True);

# %% [markdown]
# <h4><font color=darkviolet>
#     <li> Insight 5: Across the ages we see higher number of 'partnered' customers over single customers</li>
# </font></h4>

# %% [markdown]
# ### 2.3 Gender:
# Analyzing the dataset based on gender to check for similarities & differences in buying patterns for Male and Female customers

# %%
sns.countplot(data=cardio,x='Gender',hue='Product');

# %% [markdown]
# <h4><font color = darkviolet>
#     <li>Insight 6: Both Male & Female customers are most likely to buy TM195 followed by TM498 and TM798</li>
#     <li>Insight 7: Male customers seem to have nearly equal preference for TM498 and TM798</li>
#     <li>Insight 8: Female customers seem far less likely to buy TM798 than they are to buy TM498 </li>
#     </font></h4>

# %%
sns.histplot(data=cardio, x='Product', hue='Gender', multiple='dodge');

# %% [markdown]
# <h4><font color=darkviolet>
#     <li>Insight 9: TM195 and TM498 have almost equal distribution of male and female buyers</li>
#     <li>Insight 10: TM798 seems to have predominantly male customer base</li>
# </font></h4>

# %% [markdown]
# ### 2.4 Education:
# Education levels usually have high likelihood to influence purchase habits. Let us analyze our current dataset to see if education plays any role here.

# %%
sns.histplot(data=cardio, x='Education', hue='Product', multiple='dodge', kde=True);

# %% [markdown]
# <h4><font color=darkviolet>
#     <li>Insight 11: Customer with Education level under 14 seem to most likely not be buyers.</li>
#     <li>Insight 12: Customer with Education level 14 & 16 seem to be likely to buy TM195 and TM498</li>
#     <li>Insight 13: Customers with Education level over 16 seem to prefer TM798
#     </font></h4>

# %% [markdown]
# ### 2.5 Marital Status:
# Marriage is often a good inflexion point in our daily habits and lifestyles. Let us analyse the impact of Marital Status on Fitness equipment purchasing.

# %%
sns.countplot(data=cardio,x='MaritalStatus',hue='Product');

# %% [markdown]
# <h4><font color=darkviolet>
#     <li>Insight 14: While partnered customer are higher in numbers across the board, both single and parnered customers have similar buying preference with TM195 being the most popular with both groups
#     </font></h4>

# %% [markdown]
# ### 2.6 Usage:
# Usage of fitness equipment could intuitively create a preference for different products, let us analyze the impact of usage on product preferences

# %%
sns.histplot(data=cardio, x='Usage', hue='Product', multiple='dodge', kde=True);

# %% [markdown]
# <h4><font color=darkviolet>
#     <li>Insight 15: People with usage lower than 4 seem to buy TM195 and TM498 almost exclusively</li>
#     <li>Insight 16: People with usage higher than 4 seem to buy TM798 almost exclusively</li>
#     <li>Insight 17: Peoplw with usage exactly at 4 seem buy all 3 types of treadmills</li>
#     </h4></font>

# %% [markdown]
# ### 2.7 Fitness:

# %%
sns.histplot(data=cardio, x='Fitness', hue='Product', multiple='dodge', kde=True);

# %% [markdown]
# <h4><font color=darkviolet>
#     <li>Insight 18: People with Fitness lower than 4 seem to buy TM195 and TM498 almost exclusively</li>
#     <li>Insight 19: People with Fitness higher than 4 seem to buy TM798 almost exclusively</li>
#     <li>Insight 20: Peoplw with Fitness exactly at 4 seem buy all 3 types of treadmills</li>
#     </h4></font>

# %% [markdown]
# ### 2.8 Income:
# Income tends to influence our buying habits buy a lot, let us analyse how it affects treadmill purchase

# %%
sns.histplot(data=cardio, x='Income', hue='Product', multiple='dodge', kde=True);

# %% [markdown]
# <h4><font color=darkviolet>
#     <li>Insight 21: People with income 40,000 and under seem to buy TM195 and TM498 almost exclusively</li>
#     <li>Insight 22: People with income between 40,000 and 70,000 seem to buy TM195 and TM498 significantly more than TM798</li>
#     <li>Insight 23: People with income over 70,000 seem to buy TM798 almost exclusively</li>
#     </h4></font>

# %% [markdown]
# ### 2.9 Miles:

# %%
sns.histplot(data=cardio, x='Miles', hue='Product', multiple='dodge', kde=True);

# %% [markdown]
# <h4><font color=darkviolet>
#     <li>Insight 24: People with 100 Miles and under seem to buy TM195 and TM498 almost exclusively</li>
#     <li>Insight 25: People with Miles between 100 and 150 seem to buy TM195 and TM498 significantly more than TM798</li>
#     <li>Insight 26: People with Miles over 150 seem to buy TM798 almost exclusively</li>
#     </h4></font>

# %% [markdown]
# ### Multi-Variate Analysis:

# %%
sns.pairplot(cardio, hue='Product');

# %% [markdown]
# <h4><font color=darkviolet>
#     <li>Insight 27: At any given age, people with higher income, fitness, usage, education seem to be more likely to buy TM798 as evident by the violet scatter plot dots in the first column of the pairplot.</li><br>
#     <li>Insight 28: In all the rest of the categories other than age, the higher the customer is on each of these scales higher is their likely hood to buy TM798, as evidenced by the right shifted violet distribution plots in the diagonal</li><br>
#     <li>Insight 29: When faced with a choice between TM195 and TM498, more number of customers seems to gravitate towards TM195 as seen by the overlap between the red & blue distribution plots with higher red peaks</li>
# </h4></font>

# %% [markdown]
# ## <font color=darkorange>3. Insights for targeting new customers</font>

# %% [markdown]
# ### Summary:
# TM195 seems to be the most popular product, followed by TM498. As we saw in 'Profile 1', the customers for these two products are largely similar. TM798 is the 3rd or last most popular product in the dataset.
#
# <table>
#   <thead>
#     <tr>
#         <th>Products</th>
#         <th>Age</th>
#         <th>Gender</th>
#         <th>Education</th>
#         <th>Marital Status</th>
#         <th>Usage</th>
#         <th>Fitness</th>
#         <th>Income</th>
#         <th>Miles</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#         <td>TM195 & TM498</td>
#         <td>Peak at 25</td>
#         <td># of Male = Female</td>
#         <td>Less than 16</td>
#         <td>More partnered customers</td>
#         <td>Less than 4</td>
#         <td>Less than 4</td>
#         <td>Less than USD 70K</td>
#         <td>Less than 150 mi</td>
#     </tr>
#     <tr>
#         <td>TM798</td>
#         <td>Bimodal: Peaks at 25 and ~33 YO</td>
#         <td>Predominantly Male</td>
#         <td>More than 16</td>
#         <td>More partnered customers</td>
#         <td>More than 4</td>
#         <td>More than 4</td>
#         <td>More than USD 70K</td>
#         <td>More than 150 mi</td>
#     </tr>
#   </tbody>
# </table>
#
# In the end we can see that at any given age, people with higher income, fitness, usage, education seem to be more likely to buy TM798. People who fall in the lower spectrum on each of these scales, prefer TM195 and TM498. When faced with a choice between TM195 and TM498, more customers seem to gravitate towards TM195.
#
# ### Conclusion - Marketing Strategy:
# The univariate analysis and the summary table above clearly verifies the two customer profiles we created in the beginning of this project. Using this for a marketing outreach I'd suggest 'Cardio Good Fitness' store to focus more on partnered members more than singles. And within each age group market TM195 and TM498 to customers who fit with Profile 1 and market TM798 to cusotmers who fit with Profile 2.
